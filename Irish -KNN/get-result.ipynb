# %%
import joblib
model=joblib.load('KNN-iris-model.sav')

# %%
test_data=[]

for i in range(4):
   y=float(input())
   test_data.append(y) 
print(test_data)
# Out:
#  1.3
#  2.3
#  1.3
#  6.2
# [1.3, 2.3, 1.3, 6.2]

# %%
result=model.predict([test_data])

# %%
print(result)
# Out:
# [1.]
